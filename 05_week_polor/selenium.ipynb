# %%
# !pip install selenium --upgrade --force
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 978.4 kB/s eta 0:00:00m eta 0:00:016m0:00:010m
# ...
#   Using cached urllib3-2.0.2-py3-none-any.whl (123 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 313.9 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# ...
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 615.4 kB/s eta 0:00:0031m1.0 MB/s eta 0:00:01
# ...
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# ...
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# ...
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# ...
#   Using cached exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# ...
#   Using cached importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# ...
#   Using cached typing_extensions-4.6.2-py3-none-any.whl (31 kB)
# ...
#   Using cached zipp-3.15.0-py3-none-any.whl (6.8 kB)
# ...
#   Attempting uninstall: sortedcontainers
# ...

# %% [markdown]
# # selenium
# # webdriver (webbrowser/chrome/firefox)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# driver = webdriver.Firefox()
driver = webdriver.Chrome()
driver.get("http://www.python.org")# open this url
assert "Python" in driver.title # <title>Welcome to Python.org</title>
elem = driver.find_element(By.NAME, "q")# search box find name
elem.clear()# remove previouse text
elem.send_keys("pandas")
elem.send_keys(Keys.RETURN)
assert "No results found." not in driver.page_source
driver.close()
# Out:
# ----------------------------------------------------------------------
# AssertionError                       Traceback (most recent call last)
# <ipython-input-6-45573fd37a63> in <module>
#      11 elem.send_keys("pandas")
#      12 elem.send_keys(Keys.RETURN)
# ---> 13 assert "No results found." not in driver.page_source
#      14 # driver.close()
#
# AssertionError:

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

# driver = webdriver.Firefox()
driver = webdriver.Chrome()
driver.get("https://www.google.com/")# open this url
elem = driver.find_element(By.NAME, "q")# search box find name
elem.clear()# remove previouse text
time.sleep(3)
elem.send_keys("Saylani Mass IT")
elem.send_keys(Keys.RETURN)
assert "No results found." not in driver.page_source
# driver.close()

# %% [markdown]
# # GUI for Desktop application
# * TKinter
#     * only for desktop application interface
#     * only code based
# * pyqt5
#     * provide GUI for creating desktop UI
# * kivy
#     * mobile (android/IOS/Windows/mac) UI
# * web-based application
#     * django
#     * flask
#     * stremlit
