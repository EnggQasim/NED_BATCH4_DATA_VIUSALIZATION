# %%
import pandas as pd
import numpy as np


def random_date():
   
    month = np.random.randint(1,12)
    if month==2:
         day = np.random.randint(1,28)
    else:
         day = np.random.randint(1,31)
    year  = np.random.randint(1950,2015)
    dt = pd.to_datetime(f"{year}-{month}-{day}")
    return dt
    
random_date() 



no_of_records = 1000
df1 = pd.DataFrame(
    {
        "rollno":np.arange(1,no_of_records+1),
        'name': np.random.choice(['Ali','Hamza','Junaid',"Asif"],no_of_records),
        'fname': np.random.choice(['Ali','Hamza','Junaid',"Asif"],no_of_records),
        'course': np.random.choice(['AI','DS','ML',"Blockchain"],no_of_records),
        'city': np.random.choice(['KHI','ISL','LHR',None],no_of_records),
        'dob': [random_date() for i in range(no_of_records)],
        's1': np.random.randint(1,100, no_of_records),
        's2': np.random.randint(1,100, no_of_records),
        's3': np.random.randint(1,100, no_of_records),
        's4': np.random.randint(1,100, no_of_records),
        's5': np.random.randint(1,100, no_of_records),
        

    }
)
df1
# Out:
#      rollno    name   fname      course  city        dob  s1  s2  s3  s4  s5
# 0         1    Asif  Junaid  Blockchain   ISL 1957-02-13  82  17   9  46  54
# 1         2    Asif    Asif          ML   ISL 1955-05-27  89  53  10  46  44
# 2         3     Ali  Junaid          AI  None 1960-09-24  38  39  78  71  89
# 3         4     Ali   Hamza          AI   KHI 1952-03-14  30   9  77  30  14
# 4         5   Hamza  Junaid          DS   KHI 1989-03-11  38  23  54  60  34
# ..      ...     ...     ...         ...   ...        ...  ..  ..  ..  ..  ..
# 995     996  Junaid   Hamza          DS  None 1954-02-16  80  61  58   2  59
# 996     997     Ali    Asif          DS   ISL 1959-06-17  88  31  27   8  13
# 997     998   Hamza  Junaid  Blockchain   LHR 1952-08-27  17  80  12  49  71
# 998     999  Junaid   Hamza          ML  None 1993-04-25  73  52  77  62  63
# 999    1000    Asif     Ali  Blockchain  None 1950-01-06   6  74  20   1  33
#
# [1000 rows x 11 columns]

# %%
import polars as pl

# %% [raw]
# dir(pl)

# %%
df2 = pl.DataFrame(df1)
df2
# Out:
# shape: (1000, 11)
# ┌────────┬────────┬────────┬───────────┬─────┬─────┬─────┬─────┬─────┐
# │ rollno ┆ name   ┆ fname  ┆ course    ┆ ... ┆ s2  ┆ s3  ┆ s4  ┆ s5  │
# │ ---    ┆ ---    ┆ ---    ┆ ---       ┆     ┆ --- ┆ --- ┆ --- ┆ --- │
# │ i64    ┆ str    ┆ str    ┆ str       ┆     ┆ i64 ┆ i64 ┆ i64 ┆ i64 │
# ╞════════╪════════╪════════╪═══════════╪═════╪═════╪═════╪═════╪═════╡
# │ 1      ┆ Asif   ┆ Junaid ┆ Blockchai ┆ ... ┆ 17  ┆ 9   ┆ 46  ┆ 54  │
# │        ┆        ┆        ┆ n         ┆     ┆     ┆     ┆     ┆     │
# │ 2      ┆ Asif   ┆ Asif   ┆ ML        ┆ ... ┆ 53  ┆ 10  ┆ 46  ┆ 44  │
# │ 3      ┆ Ali    ┆ Junaid ┆ AI        ┆ ... ┆ 39  ┆ 78  ┆ 71  ┆ 89  │
# │ 4      ┆ Ali    ┆ Hamza  ┆ AI        ┆ ... ┆ 9   ┆ 77  ┆ 30  ┆ 14  │
# │ ...    ┆ ...    ┆ ...    ┆ ...       ┆ ... ┆ ... ┆ ... ┆ ... ┆ ... │
# │ 997    ┆ Ali    ┆ Asif   ┆ DS        ┆ ... ┆ 31  ┆ 27  ┆ 8   ┆ 13  │
# │ 998    ┆ Hamza  ┆ Junaid ┆ Blockchai ┆ ... ┆ 80  ┆ 12  ┆ 49  ┆ 71  │
# │        ┆        ┆        ┆ n         ┆     ┆     ┆     ┆     ┆     │
# │ 999    ┆ Junaid ┆ Hamza  ┆ ML        ┆ ... ┆ 52  ┆ 77  ┆ 62  ┆ 63  │
# │ 1000   ┆ Asif   ┆ Ali    ┆ Blockchai ┆ ... ┆ 74  ┆ 20  ┆ 1   ┆ 33  │
# │        ┆        ┆        ┆ n         ┆     ┆     ┆     ┆     ┆     │
# └────────┴────────┴────────┴───────────┴─────┴─────┴─────┴─────┴─────┘

# %% [markdown]
# # Polors function on dataframe

# %%
# %%time
def obtained(sub1,sub2,sub3,sub4,sub5):
    return sub1+sub2+sub3+sub4+sub5

df2[:,"s1":"s5"].apply(lambda x:obtained(*x))
# Out:
# CPU times: user 4.8 ms, sys: 0 ns, total: 4.8 ms
# Wall time: 7.79 ms
# shape: (1000, 1)
# ┌───────┐
# │ apply │
# │ ---   │
# │ i64   │
# ╞═══════╡
# │ 208   │
# │ 242   │
# │ 315   │
# │ 160   │
# │ ...   │
# │ 167   │
# │ 229   │
# │ 327   │
# │ 134   │
# └───────┘

# %%
82+17+9+46+54
# Out:
# 208

# %% [markdown]
# # pandas custome function

# %%
# %%time
def obtained(sub1,sub2,sub3,sub4,sub5):
    return sub1+sub2+sub3+sub4+sub5

df1.loc[:,"s1":"s5"].apply(lambda x:obtained(*x), axis=1)
# Out:
# CPU times: user 18.8 ms, sys: 15.7 ms, total: 34.5 ms
# Wall time: 34.8 ms
# 0      208
# 1      242
# 2      315
# 3      160
# 4      209
#       ...
# 995    260
# 996    167
# 997    229
# 998    327
# 999    134
# Length: 1000, dtype: int64
